# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import requests

from sklearn.metrics import r2_score

# %%
request = requests.get("https://lazyprogrammer.me/course_files/sp500sub.csv");

with open('../00Data/sp500sub.csv', 'wb') as file:
    file.write(request.content)

# %%
df = pd.read_csv("../00Data/sp500sub.csv", index_col="Date")

# %%
df.head(10)
# Out:
#              Open   High    Low  Close  Adj Close     Volume  Name
# Date
# 2010-01-04   9.22   9.51   9.17   9.50       9.50  1865400.0  INCY
# 2010-01-05   9.51  10.29   9.45  10.27      10.27  7608900.0  INCY
# 2010-01-06  10.38  11.09  10.35  11.00      11.00  8046700.0  INCY
# 2010-01-07  11.00  11.06  10.62  10.82      10.82  3680300.0  INCY
# 2010-01-08  10.82  11.00  10.75  10.94      10.94  1529300.0  INCY
# 2010-01-11  10.96  11.24  10.88  11.09      11.09  2280600.0  INCY
# 2010-01-12  10.99  11.00  10.34  10.36      10.36  4204600.0  INCY
# 2010-01-13  10.36  10.46  10.04  10.33      10.33  2134900.0  INCY
# 2010-01-14  10.31  10.39  10.08  10.16      10.16  2889600.0  INCY
# 2010-01-15   9.98  10.00   9.64   9.86       9.86  2953100.0  INCY

# %%
df['Name'].value_counts()
# Out:
# Name
# CAH     2265
# KIM     2264
# NEM     2264
# SLG     2264
# RSG     2264
#         ...
# ALLE    1287
# HLT     1270
# SYF     1112
# SCG      871
# IR       411
# Name: count, Length: 104, dtype: int64

# %%
goog = df[df['Name'] == 'GOOG'][['Close']].copy()

# %%
goog.plot(figsize=(15, 5));
